# %%
import sqlalchemy as db
from getpass import getpass

# %%
password = getpass("Mysql Password: ")
# Out:
# Mysql Password: ········

# %%
dbName = "Publications"
connectionData = f"mysql+pymysql://root:{password}@localhost/{dbName}"

# %%
engine = db.create_engine(connectionData)
print("Connected to server!")
# Out:
# Connected to server!

# %%
import pandas as pd

# %%
ejercicio1 = pd.read_sql_query("""
SELECT a.au_id AUTHOR_ID, a.au_lname LAST_NAME, a.au_fname FIRST_NAME, t.title AS TITLE, p.pub_name AS PUBLISHER
	FROM authors AS a
	INNER JOIN titleauthor AS ta ON a.au_id = ta.au_id
    INNER JOIN titles AS t ON ta.title_id = t.title_id
    INNER JOIN publishers AS p ON t.pub_id = p.pub_id
""", engine)
ejercicio1.head()
# Out:
#      AUTHOR_ID   LAST_NAME FIRST_NAME  \
# 0  213-46-8915       Green   Marjorie
# 1  409-56-7008      Bennet    Abraham
# 2  267-41-2394     O'Leary    Michael
# 3  724-80-9391  MacFeather    Stearns
# 4  213-46-8915       Green   Marjorie
#
#                                                TITLE             PUBLISHER
# 0                The Busy Executive's Database Guide  Algodata Infosystems
# 1                The Busy Executive's Database Guide  Algodata Infosystems
# 2  Cooking with Computers: Surreptitious Balance ...  Algodata Infosystems
# 3  Cooking with Computers: Surreptitious Balance ...  Algodata Infosystems
# 4                    You Can Combat Computer Stress!        New Moon Books

# %%
ejercicio2 = pd.read_sql_query("""
CREATE TEMPORARY TABLE  jose(
	SELECT a.au_id AUTHOR_ID, a.au_lname LAST_NAME, a.au_fname FIRST_NAME, t.title AS TITLE, p.pub_name AS PUBLISHER
	FROM authors AS a
	RIGHT JOIN titleauthor AS ta ON a.au_id = ta.au_id
    INNER JOIN titles AS t ON ta.title_id = t.title_id
    INNER JOIN publishers AS p ON t.pub_id = p.pub_id
);
""", engine)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/sqlalchemy/engine/result.py in _fetchall_impl(self)
#    1229         try:
# -> 1230             return self.cursor.fetchall()
#    1231         except AttributeError as err:
#
# AttributeError: 'NoneType' object has no attribute 'fetchall'
#
# The above exception was the direct cause of the following exception:
#
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-11-e2ac294b9b40> in <module>
#       7     INNER JOIN publishers AS p ON t.pub_id = p.pub_id
#       8 );
# ----> 9 """, engine)
#
# ~/.local/lib/python3.6/site-packages/pandas/io/sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     330         coerce_float=coerce_float,
#     331         parse_dates=parse_dates,
# ...

# %%
ejercicio22 = pd.read_sql_query("""
select AUTHOR_ID, LAST_NAME, FIRST_NAME, PUBLISHER, COUNT(*) as TITLE_COUNT from jose
group by AUTHOR_ID, PUBLISHER, LAST_NAME, FIRST_NAME
""", engine)
ejercicio22
# Out:
#       AUTHOR_ID       LAST_NAME FIRST_NAME             PUBLISHER  TITLE_COUNT
# 0   213-46-8915           Green   Marjorie  Algodata Infosystems            1
# 1   409-56-7008          Bennet    Abraham  Algodata Infosystems            1
# 2   267-41-2394         O'Leary    Michael  Algodata Infosystems            1
# 3   724-80-9391      MacFeather    Stearns  Algodata Infosystems            1
# 4   213-46-8915           Green   Marjorie        New Moon Books            1
# 5   274-80-9391        Straight       Dean  Algodata Infosystems            1
# 6   712-45-1867    del Castillo      Innes      Binnet & Hardley            1
# 7   722-51-5454        DeFrance     Michel      Binnet & Hardley            1
# 8   899-46-2035          Ringer       Anne      Binnet & Hardley            1
# 9   238-95-7766          Carson     Cheryl  Algodata Infosystems            1
# 10  427-17-2319            Dull        Ann  Algodata Infosystems            1
# ...

# %%
ejercicio3 = pd.read_sql_query("""
SELECT a.au_id AUTHOR_ID, a.au_lname LAST_NAME, a.au_fname FIRST_NAME, SUM(s.qty) AS TOTAL
	FROM authors AS a
	INNER JOIN titleauthor AS ta ON a.au_id = ta.au_id
    INNER JOIN sales AS s ON ta.title_id = s.title_id
    Group by a.au_id
    order by TOTAL DESC
    Limit 3
""", engine)
ejercicio3.head()
# Out:
#      AUTHOR_ID LAST_NAME FIRST_NAME  TOTAL
# 0  899-46-2035    Ringer       Anne  148.0
# 1  998-72-3567    Ringer     Albert  133.0
# 2  213-46-8915     Green   Marjorie   50.0

# %%
ejercicio4 = pd.read_sql_query("""
SELECT a.au_id AUTHOR_ID, a.au_lname LAST_NAME, a.au_fname FIRST_NAME, SUM(s.qty) AS TOTAL
	FROM authors AS a
	LEFT JOIN titleauthor AS ta ON a.au_id = ta.au_id
    LEFT JOIN sales AS s ON ta.title_id = s.title_id
    Group by a.au_id
    order by TOTAL DESC
""", engine)
ejercicio4
# Out:
#       AUTHOR_ID       LAST_NAME   FIRST_NAME  TOTAL
# 0   899-46-2035          Ringer         Anne  148.0
# 1   998-72-3567          Ringer       Albert  133.0
# 2   213-46-8915           Green     Marjorie   50.0
# 3   846-92-7186          Hunter       Sheryl   50.0
# 4   427-17-2319            Dull          Ann   50.0
# 5   267-41-2394         O'Leary      Michael   45.0
# 6   724-80-9391      MacFeather      Stearns   45.0
# 7   807-91-6654        Panteley       Sylvia   40.0
# 8   722-51-5454        DeFrance       Michel   40.0
# 9   238-95-7766          Carson       Cheryl   30.0
# 10  486-29-1786        Locksley     Charlene   25.0
# 11  472-27-2349      Gringlesby         Burt   20.0
# 12  648-92-1872  Blotchet-Halls     Reginald   20.0
# 13  672-71-3249        Yokomoto        Akiko   20.0
# 14  756-30-7391          Karsen        Livia   20.0
# 15  172-32-1176           White      Johnson   15.0
# 16  274-80-9391        Straight         Dean   15.0
# ...
