# %%
import os
import json
from dotenv import load_dotenv
load_dotenv()
import requests

# %%
def getFromGithub(endpoint, queryParams={}):
    url = f"https://api.github.com{endpoint}"

    apiKey = os.getenv("pk")
    if not apiKey:
        raise ValueError("Please setup the GITHUB_APIKEY env variable")
    headers = {
        "Authorization": f"token {apiKey}"
    }
    
    res = requests.get(url, headers=headers, params=queryParams)
    print(res.url)
    return res.json()

# %%
sha = getFromGithub("/repos/ironhack-datalabs/scavenger/branches/master")
# Out:
# https://api.github.com/repos/ironhack-datalabs/scavenger/branches/master

# %%
tree = getFromGithub("/repos/ironhack-datalabs/scavenger/git/trees/9308ccc8a4c34c5e3a991ee815222a9691c32476", {"recursive":"true"})
print(tree)
# Out:
# https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees/9308ccc8a4c34c5e3a991ee815222a9691c32476?recursive=true
# ...

# %%
for x in range(len(tree["tree"])):
    if ".scavengerhunt" in (tree["tree"][x]["path"]):
        print(tree["tree"][x]["url"])
# Out:
# https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/1c9064284a24b3486015eafdb391b141c27ada2b
# https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/e351fb73264581ce26504b97ef07daea35116f32
# https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/209e3ef4b6247ce746048d5711befda46206d235
# https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/6abb415e0ae3450be0f323113bcca2af195ebbff
# https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/fb828e4a926b0a84fc16111fc0ee3eeec41f0ce7
# https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/bf3efa02f721c40c03a613824e345243a35f6812
# https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/3aaf448b40f878cf3067e2323616143bdde600de
# https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/397b22b2dc371e8db59ed327f0b75321e4c0d0f2
# https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/f5cb13223fdc1b11f4cfbbe1694f533b3c579fa0
# ...

# %%
trials= getFromGithub("/repos/ironhack-datalabs/scavenger/commits", {"sha":"1c9064284a24b3486015eafdb391b141c27ada2b"})
print(trials)
# Out:
# https://api.github.com/repos/ironhack-datalabs/scavenger/commits?sha=1c9064284a24b3486015eafdb391b141c27ada2b
# []

# %%
def getFromGithub1(content,queryParams={}):

    apiKey = os.getenv("pk")
    if not apiKey:
        raise ValueError("Please setup the GITHUB_APIKEY env variable")
    headers = {
        "Authorization": f"token {apiKey}"
    }
    
    res = requests.get(content, headers=headers, params=queryParams)
    print(res.url)
    return res.json()

# %%
commit1 = getFromGithub("/repos/ironhack-datalabs/scavenger/commits")
commit2 = commit1[0]['sha']
tree = getFromGithub("/repos/ironhack-datalabs/scavenger/commits", {'sha': '9308ccc8a4c34c5e3a991ee815222a9691c32476'})
print(tree[0]["url"])
# Out:
# https://api.github.com/repos/ironhack-datalabs/scavenger/commits
# https://api.github.com/repos/ironhack-datalabs/scavenger/commits?sha=9308ccc8a4c34c5e3a991ee815222a9691c32476
# https://api.github.com/repos/ironhack-datalabs/scavenger/commits/9308ccc8a4c34c5e3a991ee815222a9691c32476

# %%
print(tree[0]["url"])
# Out:
# https://api.github.com/repos/ironhack-datalabs/scavenger/commits/9308ccc8a4c34c5e3a991ee815222a9691c32476

# %%
final = getFromGithub("/repos/ironhack-datalabs/scavenger/commits/9308ccc8a4c34c5e3a991ee815222a9691c32476")
print(final)
# Out:
# https://api.github.com/repos/ironhack-datalabs/scavenger/commits/9308ccc8a4c34c5e3a991ee815222a9691c32476
# ...

# %%
for i in range(len(final['files'])):
    try:
        print(final['files'][i]['patch'])
    
    except:
        pass
#In data science 80 percent of time spent is preparing 20 percent of time is spent complaining about the need to prepare data
# Out:
# @@ -0,0 +1 @@
# +.DS_Store
# @@ -0,0 +1 @@
# +of
# @@ -0,0 +1 @@
# +spent
# @@ -0,0 +1 @@
# +20
# @@ -0,0 +1 @@
# +time
# @@ -0,0 +1 @@
# +need
# @@ -0,0 +1 @@
# +to
# @@ -0,0 +1 @@
# +percent
# @@ -0,0 +1 @@
# +complaining
# @@ -0,0 +1 @@
# +is
# @@ -0,0 +1 @@
# +data.
# @@ -0,0 +1 @@
# +preparing
# @@ -0,0 +1 @@
# +of
# @@ -0,0 +1 @@
# +data,
# @@ -0,0 +1 @@
# +prepare
# @@ -0,0 +1 @@
# +the
# @@ -0,0 +1 @@
# +science,
# @@ -0,0 +1 @@
# +80
# @@ -0,0 +1 @@
# +about
# @@ -0,0 +1 @@
# +spent
# @@ -0,0 +1 @@
# +data
# @@ -0,0 +1 @@
# +percent
# @@ -0,0 +1 @@
# +time
# @@ -0,0 +1 @@
# +is
# @@ -0,0 +1 @@
# +In

# %%
#
