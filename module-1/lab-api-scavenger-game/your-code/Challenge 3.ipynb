# %% [markdown]
# # Challenge 3

# %%
import os
import requests
from dotenv import load_dotenv
import json
import re
load_dotenv()
# Out:
# True

# %%
url = "https://github.com/ironhack-datalabs/scavenger"

# %%
res = requests.get(url)
res
# Out:
# <Response [200]>

# %%
def getFromGithub(endpoint, queryParams={}):
    url = f"https://api.github.com{endpoint}"

    apiKey = os.getenv("token")
    if not apiKey:
        raise ValueError("Please setup the GITHUB_APIKEY env variable")
    headers = {
        "Authorization": f"token {apiKey}"
    }
    
    res = requests.get(url, headers=headers, params=queryParams)
    return res.json()

# %%
files=getFromGithub("/repos/ironhack-datalabs/scavenger/contents")

# %%
files
# Out:
# [{'name': '.gitignore',
#   'path': '.gitignore',
#   'sha': 'e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf',
#   'size': 10,
#   'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/.gitignore?ref=master',
#   'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/master/.gitignore',
#   'git_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf',
#   'download_url': 'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/.gitignore',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/.gitignore?ref=master',
#    'git': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf',
#    'html': 'https://github.com/ironhack-datalabs/scavenger/blob/master/.gitignore'}},
#  {'name': '15024',
#   'path': '15024',
#   'sha': '2945e51c87ad5da893c954afcf092f06343bbb7d',
#   'size': 0,
# ...

# %%
file_list=[]
for x in files:
    if x["name"] != ".gitignore":
        file_list.append(x["git_url"])

# %%
repos=[]
for i in range(len(file_list)):
    repos.append(file_list[i][22:])

# %%
l = []
for x in repos: 
    l.append(getFromGithub(str(x)))
l
# Out:
# [{'sha': '2945e51c87ad5da893c954afcf092f06343bbb7d',
#   'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees/2945e51c87ad5da893c954afcf092f06343bbb7d',
#   'tree': [{'path': '.0006.scavengerhunt',
#     'mode': '100644',
#     'type': 'blob',
#     'sha': '1c9064284a24b3486015eafdb391b141c27ada2b',
#     'size': 3,
#     'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/1c9064284a24b3486015eafdb391b141c27ada2b'},
#    {'path': '40',
#     'mode': '100644',
#     'type': 'blob',
#     'sha': 'e69de29bb2d1d6434b8b29ae775ad8c2e48c5391',
#     'size': 0,
#     'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/e69de29bb2d1d6434b8b29ae775ad8c2e48c5391'},
#    {'path': '74',
#     'mode': '100644',
#     'type': 'blob',
#     'sha': 'e69de29bb2d1d6434b8b29ae775ad8c2e48c5391',
#     'size': 0,
#     'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/e69de29bb2d1d6434b8b29ae775ad8c2e48c5391'},
# ...

# %%
for i in l:
    for x in i["tree"]: 
        sorted(i, key=['path'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-e29b0a6b4e20> in <module>
#       1 for i in l:
#       2     for x in i["tree"]:
# ----> 3         sorted(i, key=['path'])
#       4
#
# TypeError: 'list' object is not callable

# %%
scavengerhunt_url=[]
for i in l:
    for x in i["tree"]:
        if '.scavengerhunt' in x['path']:
            scavengerhunt_url.append(x['url'])

# %%
scavengerhunt_url_repos=[]
for i in range(len(scavengerhunt_url)):
    scavengerhunt_url_repos.append(scavengerhunt_url[i][22:])

# %%
open_scavengerhunt_dict = []
for x in scavengerhunt_url_repos: 
    open_scavengerhunt_dict.append(getFromGithub(str(x)))
open_scavengerhunt_dict
# Out:
# [{'sha': '1c9064284a24b3486015eafdb391b141c27ada2b',
#   'node_id': 'MDQ6QmxvYjE2MjM3NTE4MToxYzkwNjQyODRhMjRiMzQ4NjAxNWVhZmRiMzkxYjE0MWMyN2FkYTJi',
#   'size': 3,
#   'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/1c9064284a24b3486015eafdb391b141c27ada2b',
#   'content': 'b2YK\n',
#   'encoding': 'base64'},
#  {'sha': 'e351fb73264581ce26504b97ef07daea35116f32',
#   'node_id': 'MDQ6QmxvYjE2MjM3NTE4MTplMzUxZmI3MzI2NDU4MWNlMjY1MDRiOTdlZjA3ZGFlYTM1MTE2ZjMy',
#   'size': 6,
#   'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/e351fb73264581ce26504b97ef07daea35116f32',
#   'content': 'c3BlbnQK\n',
#   'encoding': 'base64'},
#  {'sha': '209e3ef4b6247ce746048d5711befda46206d235',
#   'node_id': 'MDQ6QmxvYjE2MjM3NTE4MToyMDllM2VmNGI2MjQ3Y2U3NDYwNDhkNTcxMWJlZmRhNDYyMDZkMjM1',
#   'size': 3,
#   'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/209e3ef4b6247ce746048d5711befda46206d235',
#   'content': 'MjAK\n',
# ...

# %%
import base64

# %%
content = []

# %%
for i in open_scavengerhunt_dict: 
    content.append(i['content'])

# %%
content
# Out:
# ['b2YK\n',
#  'c3BlbnQK\n',
#  'MjAK\n',
#  'dGltZQo=\n',
#  'bmVlZAo=\n',
#  'dG8K\n',
#  'cGVyY2VudAo=\n',
#  'Y29tcGxhaW5pbmcK\n',
#  'aXMK\n',
#  'ZGF0YS4K\n',
#  'cHJlcGFyaW5nCg==\n',
#  'b2YK\n',
#  'ZGF0YSwK\n',
#  'cHJlcGFyZQo=\n',
#  'dGhlCg==\n',
#  'c2NpZW5jZSwK\n',
#  'ODAK\n',
#  'YWJvdXQK\n',
#  'c3BlbnQK\n',
#  'ZGF0YQo=\n',
#  'cGVyY2VudAo=\n',
#  'dGltZQo=\n',
#  'aXMK\n',
#  'SW4K\n']

# %%
joke = []
for i in content: 
    joke.append(base64.b64decode(f"{i}"))

# %%
joke
# Out:
# [b'of\n',
#  b'spent\n',
#  b'20\n',
#  b'time\n',
#  b'need\n',
#  b'to\n',
#  b'percent\n',
#  b'complaining\n',
#  b'is\n',
#  b'data.\n',
#  b'preparing\n',
#  b'of\n',
#  b'data,\n',
#  b'prepare\n',
#  b'the\n',
#  b'science,\n',
#  b'80\n',
#  b'about\n',
#  b'spent\n',
#  b'data\n',
#  b'percent\n',
#  b'time\n',
#  b'is\n',
#  b'In\n']
