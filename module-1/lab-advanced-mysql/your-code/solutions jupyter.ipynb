# %%
import sqlalchemy as db
from getpass import getpass

# %%
password = getpass("Mysql Password: ")
# Out:
# Mysql Password: ········

# %%
dbName = "publications"
connectionData = f"mysql+pymysql://root:{password}@localhost/{dbName}"

# %%
engine = db.create_engine(connectionData)
print("Connected to server!")
# Out:
# Connected to server!

# %%
import pandas as pd

# %% [markdown]
# Challenge 1

# %%
df = pd.read_sql_query("""
SELECT authors.au_id AUTHORID,  titles.title, (titles.price * sales.qty * titles.royalty / 100 * titleauthor.royaltyper / 100) AS ROYALTY
 
	FROM titles
	INNER JOIN titleauthor 
    on titles.title_id = titleauthor.title_id 
    INNER JOIN authors 
    on titleauthor.au_id = authors.au_id
    INNER JOIN sales 
    on sales.title_id = titles.title_id
    INNER JOIN roysched
    on titles.title_id = roysched.title_id
    order by ROYALTY desc 
""", engine)
df
# Out:
#         AUTHORID                     title  ROYALTY
# 0    238-95-7766  But Is It User Friendly?  110.160
# 1    238-95-7766  But Is It User Friendly?  110.160
# 2    238-95-7766  But Is It User Friendly?  110.160
# 3    238-95-7766  But Is It User Friendly?  110.160
# 4    238-95-7766  But Is It User Friendly?  110.160
# ..           ...                       ...      ...
# 162  899-46-2035       Is Anger the Enemy?    1.971
# 163  998-72-3567       Is Anger the Enemy?    1.971
# 164  998-72-3567       Is Anger the Enemy?    1.971
# 165  998-72-3567       Is Anger the Enemy?    1.971
# 166  998-72-3567       Is Anger the Enemy?    1.971
#
# [167 rows x 3 columns]

# %%
df = pd.read_sql_query("""
SELECT authors.au_id AUTHORID,  titles.title, sum(titles.price * sales.qty * titles.royalty / 100 * titleauthor.royaltyper / 100) AS ROYALTY
 
	FROM titles
	INNER JOIN titleauthor 
    on titles.title_id = titleauthor.title_id 
    INNER JOIN authors 
    on titleauthor.au_id = authors.au_id
    INNER JOIN sales 
    on sales.title_id = titles.title_id
    INNER JOIN roysched
    on titles.title_id = roysched.title_id
    group by authors.au_id,titles.title_id
    order by ROYALTY desc
""", engine)
df
# Out:
#        AUTHORID                                              title  ROYALTY
# 0   807-91-6654  Onions, Leeks, and Garlic: Cooking Secrets of ...  670.400
# 1   238-95-7766                           But Is It User Friendly?  550.800
# 2   899-46-2035                                Is Anger the Enemy?  283.824
# 3   998-72-3567                                Is Anger the Enemy?  283.824
# 4   274-80-9391                      Straight Talk About Computers  239.880
# 5   648-92-1872          Fifty Years in Buckingham Palace Kitchens  234.220
# 6   213-46-8915                    You Can Combat Computer Stress!  200.928
# 7   427-17-2319                          Secrets of Silicon Valley  200.000
# 8   846-92-7186                          Secrets of Silicon Valley  200.000
# 9   722-51-5454                              The Gourmet Microwave  172.224
# 10  756-30-7391  Computer Phobic AND Non-Phobic Individuals: Be...  161.925
# 11  712-45-1867                  Silicon Valley Gastronomic Treats  143.928
# 12  724-80-9391  Cooking with Computers: Surreptitious Balance ...  143.400
# 13  172-32-1176      Prolonged Data Deprivation: Four Case Studies  119.940
# 14  267-41-2394  Cooking with Computers: Surreptitious Balance ...   95.600
# 15  998-72-3567                                  Life Without Fear   70.000
# 16  899-46-2035                              The Gourmet Microwave   57.408
# 17  724-80-9391  Computer Phobic AND Non-Phobic Individuals: Be...   53.975
# 18  486-29-1786                Emotional Security: A New Algorithm   39.950
# 19  409-56-7008                The Busy Executive's Database Guide   35.982
# 20  672-71-3249                                     Sushi, Anyone?   35.976
# 21  267-41-2394                                     Sushi, Anyone?   26.982
# 22  472-27-2349                                     Sushi, Anyone?   26.982
# 23  213-46-8915                The Busy Executive's Database Guide   23.988

# %%
df = pd.read_sql_query("""
 SELECT authors.au_id AUTHORID, (titles.advance + sum(titles.price * sales.qty * titles.royalty / 100 * titleauthor.royaltyper / 100)) AS TOTAL_PROFITS
 
	FROM titles
	INNER JOIN titleauthor 
    on titles.title_id = titleauthor.title_id 
    INNER JOIN authors 
    on titleauthor.au_id = authors.au_id
    INNER JOIN sales 
    on sales.title_id = titles.title_id
    INNER JOIN roysched
    on titles.title_id = roysched.title_id
    group by authors.au_id,titles.title_id
    order by TOTAL_PROFITS desc 
	LIMIT 3
""", engine)
df
# Out:
#       AUTHORID  TOTAL_PROFITS
# 0  722-51-5454      15172.224
# 1  899-46-2035      15057.408
# 2  213-46-8915      10325.928

# %% [markdown]
# Challenge 2

# %%
df = pd.read_sql_query("""

CREATE TEMPORARY TABLE C1(
	AUTHORID VARCHAR(30),  TITLES VARCHAR(90),  ROYALTY FLOAT(30)
 );
INSERT INTO C1
SELECT authors.au_id AUTHORID,  titles.title, sum(titles.price * sales.qty * titles.royalty / 100 * titleauthor.royaltyper / 100) AS ROYALTY
 
	FROM titles
	INNER JOIN titleauthor 
    on titles.title_id = titleauthor.title_id 
    INNER JOIN authors 
    on titleauthor.au_id = authors.au_id
    INNER JOIN sales 
    on sales.title_id = titles.title_id
    INNER JOIN roysched
    on titles.title_id = roysched.title_id
    group by authors.au_id,titles.title_id
    order by ROYALTY desc
""", engine)
df
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1282                 if not evt_handled:
# -> 1283                     self.dialect.do_execute(
#    1284                         cursor, statement, parameters, context
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     589     def do_execute(self, cursor, statement, parameters, context=None):
# --> 590         cursor.execute(statement, parameters)
#     591
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     327         self._clear_result()
# --> 328         conn.query(q)
#     329         self._do_get_result()
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     516         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 517         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     518         return self._affected_rows
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     731             result = MySQLResult(self)
# --> 732             result.read()
#     733         self._result = result
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in read(self)
#    1074         try:
# -> 1075             first_packet = self.connection._read_packet()
#    1076
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     683         packet = packet_type(buff, self.encoding)
# --> 684         packet.check_error()
#     685         return packet
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\protocol.py in check_error(self)
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# ProgrammingError: (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'INSERT INTO C1\nSELECT authors.au_id AUTHORID,  titles.title, sum(titles.price * ' at line 4")
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-12-b6831c1431ce> in <module>
# ----> 1 df = pd.read_sql_query("""
#       2
#       3 CREATE TEMPORARY TABLE C1(
#       4         AUTHORID VARCHAR(30),  TITLES VARCHAR(90),  ROYALTY FLOAT(30)
#       5  );
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pandas\io\sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     324     """
#     325     pandas_sql = pandasSQL_builder(con)
# --> 326     return pandas_sql.read_query(
#     327         sql,
#     328         index_col=index_col,
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1216         args = _convert_params(sql, params)
#    1217
# -> 1218         result = self.execute(*args)
#    1219         columns = result.keys()
#    1220
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1085     def execute(self, *args, **kwargs):
#    1086         """Simple passthrough to SQLAlchemy connectable"""
# -> 1087         return self.connectable.execute(*args, **kwargs)
#    1088
#    1089     def read_table(
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    2242
#    2243         connection = self._contextual_connect(close_with_result=True)
# -> 2244         return connection.execute(statement, *multiparams, **params)
#    2245
#    2246     def scalar(self, statement, *multiparams, **params):
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#    1010         """
#    1011         if isinstance(object_, util.string_types[0]):
# -> 1012             return self._execute_text(object_, multiparams, params)
#    1013         try:
#    1014             meth = object_._execute_on_connection
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\base.py in _execute_text(self, statement, multiparams, params)
#    1179         dialect = self.dialect
#    1180         parameters = _distill_params(multiparams, params)
# -> 1181         ret = self._execute_context(
#    1182             dialect,
#    1183             dialect.execution_ctx_cls._init_statement,
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1321
#    1322         except BaseException as e:
# -> 1323             self._handle_dbapi_exception(
#    1324                 e, statement, parameters, cursor, context
#    1325             )
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1515                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1516             elif should_wrap:
# -> 1517                 util.raise_(
#    1518                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1519                 )
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1281                             break
#    1282                 if not evt_handled:
# -> 1283                     self.dialect.do_execute(
#    1284                         cursor, statement, parameters, context
#    1285                     )
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     588
#     589     def do_execute(self, cursor, statement, parameters, context=None):
# --> 590         cursor.execute(statement, parameters)
#     591
#     592     def do_execute_no_params(self, cursor, statement, context=None):
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     168         query = self.mogrify(query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#     172         return result
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     326         self._last_executed = q
#     327         self._clear_result()
# --> 328         conn.query(q)
#     329         self._do_get_result()
#     330         return self.rowcount
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     515                 sql = sql.encode(self.encoding, 'surrogateescape')
#     516         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 517         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     518         return self._affected_rows
#     519
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     730         else:
#     731             result = MySQLResult(self)
# --> 732             result.read()
#     733         self._result = result
#     734         if result.server_status is not None:
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in read(self)
#    1073     def read(self):
#    1074         try:
# -> 1075             first_packet = self.connection._read_packet()
#    1076
#    1077             if first_packet.is_ok_packet():
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     682
#     683         packet = packet_type(buff, self.encoding)
# --> 684         packet.check_error()
#     685         return packet
#     686
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\protocol.py in check_error(self)
#     218             errno = self.read_uint16()
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#     222     def dump(self):
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     107         errval = data[3:].decode('utf-8', 'replace')
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# ProgrammingError: (pymysql.err.ProgrammingError) (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'INSERT INTO C1\nSELECT authors.au_id AUTHORID,  titles.title, sum(titles.price * ' at line 4")
# [SQL:
#
# CREATE TEMPORARY TABLE C1(
# 	AUTHORID VARCHAR(30),  TITLES VARCHAR(90),  ROYALTY FLOAT(30)
#  );
# INSERT INTO C1
# SELECT authors.au_id AUTHORID,  titles.title, sum(titles.price * sales.qty * titles.royalty / 100 * titleauthor.royaltyper / 100) AS ROYALTY
#
# 	FROM titles
# 	INNER JOIN titleauthor
#     on titles.title_id = titleauthor.title_id
#     INNER JOIN authors
#     on titleauthor.au_id = authors.au_id
#     INNER JOIN sales
#     on sales.title_id = titles.title_id
#     INNER JOIN roysched
#     on titles.title_id = roysched.title_id
#     group by authors.au_id,titles.title_id
#     order by ROYALTY desc
# ]
# (Background on this error at: http://sqlalche.me/e/f405)

# %%
df = pd.read_sql_query("""
DROP TABLE C2;
CREATE TEMPORARY TABLE C2(
	AUTHORID VARCHAR(30),  TITLES VARCHAR(90),  ROYALTY FLOAT(30)
 );
INSERT INTO C2
   SELECT authors.au_id AUTHORID,  titles.title, sum(titles.price * sales.qty * titles.royalty / 100 * titleauthor.royaltyper / 100) AS ROYALTY
 
	FROM titles
	INNER JOIN titleauthor 
    on titles.title_id = titleauthor.title_id 
    INNER JOIN authors 
    on titleauthor.au_id = authors.au_id
    INNER JOIN sales 
    on sales.title_id = titles.title_id
    INNER JOIN roysched
    on titles.title_id = roysched.title_id
    group by authors.au_id,titles.title_id
    order by ROYALTY desc 
""", engine)
df
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1282                 if not evt_handled:
# -> 1283                     self.dialect.do_execute(
#    1284                         cursor, statement, parameters, context
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     589     def do_execute(self, cursor, statement, parameters, context=None):
# --> 590         cursor.execute(statement, parameters)
#     591
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     327         self._clear_result()
# --> 328         conn.query(q)
#     329         self._do_get_result()
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     516         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 517         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     518         return self._affected_rows
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     731             result = MySQLResult(self)
# --> 732             result.read()
#     733         self._result = result
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in read(self)
#    1074         try:
# -> 1075             first_packet = self.connection._read_packet()
#    1076
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     683         packet = packet_type(buff, self.encoding)
# --> 684         packet.check_error()
#     685         return packet
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\protocol.py in check_error(self)
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# ProgrammingError: (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'CREATE TEMPORARY TABLE C2(\n\tAUTHORID VARCHAR(30),  TITLES VARCHAR(90),  ROYALTY ' at line 2")
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-13-fea0f0d50881> in <module>
# ----> 1 df = pd.read_sql_query("""
#       2 DROP TABLE C2;
#       3 CREATE TEMPORARY TABLE C2(
#       4         AUTHORID VARCHAR(30),  TITLES VARCHAR(90),  ROYALTY FLOAT(30)
#       5  );
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pandas\io\sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     324     """
#     325     pandas_sql = pandasSQL_builder(con)
# --> 326     return pandas_sql.read_query(
#     327         sql,
#     328         index_col=index_col,
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1216         args = _convert_params(sql, params)
#    1217
# -> 1218         result = self.execute(*args)
#    1219         columns = result.keys()
#    1220
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1085     def execute(self, *args, **kwargs):
#    1086         """Simple passthrough to SQLAlchemy connectable"""
# -> 1087         return self.connectable.execute(*args, **kwargs)
#    1088
#    1089     def read_table(
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    2242
#    2243         connection = self._contextual_connect(close_with_result=True)
# -> 2244         return connection.execute(statement, *multiparams, **params)
#    2245
#    2246     def scalar(self, statement, *multiparams, **params):
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#    1010         """
#    1011         if isinstance(object_, util.string_types[0]):
# -> 1012             return self._execute_text(object_, multiparams, params)
#    1013         try:
#    1014             meth = object_._execute_on_connection
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\base.py in _execute_text(self, statement, multiparams, params)
#    1179         dialect = self.dialect
#    1180         parameters = _distill_params(multiparams, params)
# -> 1181         ret = self._execute_context(
#    1182             dialect,
#    1183             dialect.execution_ctx_cls._init_statement,
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1321
#    1322         except BaseException as e:
# -> 1323             self._handle_dbapi_exception(
#    1324                 e, statement, parameters, cursor, context
#    1325             )
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1515                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1516             elif should_wrap:
# -> 1517                 util.raise_(
#    1518                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1519                 )
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1281                             break
#    1282                 if not evt_handled:
# -> 1283                     self.dialect.do_execute(
#    1284                         cursor, statement, parameters, context
#    1285                     )
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     588
#     589     def do_execute(self, cursor, statement, parameters, context=None):
# --> 590         cursor.execute(statement, parameters)
#     591
#     592     def do_execute_no_params(self, cursor, statement, context=None):
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     168         query = self.mogrify(query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#     172         return result
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     326         self._last_executed = q
#     327         self._clear_result()
# --> 328         conn.query(q)
#     329         self._do_get_result()
#     330         return self.rowcount
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     515                 sql = sql.encode(self.encoding, 'surrogateescape')
#     516         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 517         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     518         return self._affected_rows
#     519
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     730         else:
#     731             result = MySQLResult(self)
# --> 732             result.read()
#     733         self._result = result
#     734         if result.server_status is not None:
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in read(self)
#    1073     def read(self):
#    1074         try:
# -> 1075             first_packet = self.connection._read_packet()
#    1076
#    1077             if first_packet.is_ok_packet():
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     682
#     683         packet = packet_type(buff, self.encoding)
# --> 684         packet.check_error()
#     685         return packet
#     686
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\protocol.py in check_error(self)
#     218             errno = self.read_uint16()
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#     222     def dump(self):
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     107         errval = data[3:].decode('utf-8', 'replace')
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# ProgrammingError: (pymysql.err.ProgrammingError) (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'CREATE TEMPORARY TABLE C2(\n\tAUTHORID VARCHAR(30),  TITLES VARCHAR(90),  ROYALTY ' at line 2")
# [SQL:
# DROP TABLE C2;
# CREATE TEMPORARY TABLE C2(
# 	AUTHORID VARCHAR(30),  TITLES VARCHAR(90),  ROYALTY FLOAT(30)
#  );
# INSERT INTO C2
#    SELECT authors.au_id AUTHORID,  titles.title, sum(titles.price * sales.qty * titles.royalty / 100 * titleauthor.royaltyper / 100) AS ROYALTY
#
# 	FROM titles
# 	INNER JOIN titleauthor
#     on titles.title_id = titleauthor.title_id
#     INNER JOIN authors
#     on titleauthor.au_id = authors.au_id
#     INNER JOIN sales
#     on sales.title_id = titles.title_id
#     INNER JOIN roysched
#     on titles.title_id = roysched.title_id
#     group by authors.au_id,titles.title_id
#     order by ROYALTY desc
# ]
# (Background on this error at: http://sqlalche.me/e/f405)

# %%
df = pd.read_sql_query("""
DROP TABLE C3;
CREATE TEMPORARY TABLE C3(
	AUTHORID VARCHAR(30), TOTAL_PROFITS FLOAT(30)
 );
INSERT INTO C3
	SELECT authors.au_id AUTHORID, (titles.advance + sum(titles.price * sales.qty * titles.royalty / 100 * titleauthor.royaltyper / 100)) AS TOTAL_PROFITS
 
	FROM titles
	INNER JOIN titleauthor 
    on titles.title_id = titleauthor.title_id 
    INNER JOIN authors 
    on titleauthor.au_id = authors.au_id
    INNER JOIN sales 
    on sales.title_id = titles.title_id
    INNER JOIN roysched
    on titles.title_id = roysched.title_id
    group by authors.au_id,titles.title_id
    order by TOTAL_PROFITS desc 
	LIMIT 3; 
""", engine)
df
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1282                 if not evt_handled:
# -> 1283                     self.dialect.do_execute(
#    1284                         cursor, statement, parameters, context
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     589     def do_execute(self, cursor, statement, parameters, context=None):
# --> 590         cursor.execute(statement, parameters)
#     591
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     327         self._clear_result()
# --> 328         conn.query(q)
#     329         self._do_get_result()
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     516         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 517         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     518         return self._affected_rows
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     731             result = MySQLResult(self)
# --> 732             result.read()
#     733         self._result = result
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in read(self)
#    1074         try:
# -> 1075             first_packet = self.connection._read_packet()
#    1076
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     683         packet = packet_type(buff, self.encoding)
# --> 684         packet.check_error()
#     685         return packet
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\protocol.py in check_error(self)
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# ProgrammingError: (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'CREATE TEMPORARY TABLE C3(\n\tAUTHORID VARCHAR(30), TOTAL_PROFITS FLOAT(30)\n );\nIN' at line 2")
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-14-a529e81e8306> in <module>
# ----> 1 df = pd.read_sql_query("""
#       2 DROP TABLE C3;
#       3 CREATE TEMPORARY TABLE C3(
#       4         AUTHORID VARCHAR(30), TOTAL_PROFITS FLOAT(30)
#       5  );
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pandas\io\sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     324     """
#     325     pandas_sql = pandasSQL_builder(con)
# --> 326     return pandas_sql.read_query(
#     327         sql,
#     328         index_col=index_col,
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1216         args = _convert_params(sql, params)
#    1217
# -> 1218         result = self.execute(*args)
#    1219         columns = result.keys()
#    1220
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1085     def execute(self, *args, **kwargs):
#    1086         """Simple passthrough to SQLAlchemy connectable"""
# -> 1087         return self.connectable.execute(*args, **kwargs)
#    1088
#    1089     def read_table(
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    2242
#    2243         connection = self._contextual_connect(close_with_result=True)
# -> 2244         return connection.execute(statement, *multiparams, **params)
#    2245
#    2246     def scalar(self, statement, *multiparams, **params):
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#    1010         """
#    1011         if isinstance(object_, util.string_types[0]):
# -> 1012             return self._execute_text(object_, multiparams, params)
#    1013         try:
#    1014             meth = object_._execute_on_connection
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\base.py in _execute_text(self, statement, multiparams, params)
#    1179         dialect = self.dialect
#    1180         parameters = _distill_params(multiparams, params)
# -> 1181         ret = self._execute_context(
#    1182             dialect,
#    1183             dialect.execution_ctx_cls._init_statement,
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1321
#    1322         except BaseException as e:
# -> 1323             self._handle_dbapi_exception(
#    1324                 e, statement, parameters, cursor, context
#    1325             )
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1515                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1516             elif should_wrap:
# -> 1517                 util.raise_(
#    1518                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1519                 )
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1281                             break
#    1282                 if not evt_handled:
# -> 1283                     self.dialect.do_execute(
#    1284                         cursor, statement, parameters, context
#    1285                     )
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     588
#     589     def do_execute(self, cursor, statement, parameters, context=None):
# --> 590         cursor.execute(statement, parameters)
#     591
#     592     def do_execute_no_params(self, cursor, statement, context=None):
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     168         query = self.mogrify(query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#     172         return result
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     326         self._last_executed = q
#     327         self._clear_result()
# --> 328         conn.query(q)
#     329         self._do_get_result()
#     330         return self.rowcount
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     515                 sql = sql.encode(self.encoding, 'surrogateescape')
#     516         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 517         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     518         return self._affected_rows
#     519
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     730         else:
#     731             result = MySQLResult(self)
# --> 732             result.read()
#     733         self._result = result
#     734         if result.server_status is not None:
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in read(self)
#    1073     def read(self):
#    1074         try:
# -> 1075             first_packet = self.connection._read_packet()
#    1076
#    1077             if first_packet.is_ok_packet():
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     682
#     683         packet = packet_type(buff, self.encoding)
# --> 684         packet.check_error()
#     685         return packet
#     686
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\protocol.py in check_error(self)
#     218             errno = self.read_uint16()
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#     222     def dump(self):
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     107         errval = data[3:].decode('utf-8', 'replace')
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# ProgrammingError: (pymysql.err.ProgrammingError) (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'CREATE TEMPORARY TABLE C3(\n\tAUTHORID VARCHAR(30), TOTAL_PROFITS FLOAT(30)\n );\nIN' at line 2")
# [SQL:
# DROP TABLE C3;
# CREATE TEMPORARY TABLE C3(
# 	AUTHORID VARCHAR(30), TOTAL_PROFITS FLOAT(30)
#  );
# INSERT INTO C3
# 	SELECT authors.au_id AUTHORID, (titles.advance + sum(titles.price * sales.qty * titles.royalty / 100 * titleauthor.royaltyper / 100)) AS TOTAL_PROFITS
#
# 	FROM titles
# 	INNER JOIN titleauthor
#     on titles.title_id = titleauthor.title_id
#     INNER JOIN authors
#     on titleauthor.au_id = authors.au_id
#     INNER JOIN sales
#     on sales.title_id = titles.title_id
#     INNER JOIN roysched
#     on titles.title_id = roysched.title_id
#     group by authors.au_id,titles.title_id
#     order by TOTAL_PROFITS desc
# 	LIMIT 3;
# ]
# (Background on this error at: http://sqlalche.me/e/f405)

# %% [markdown]
# Challenge 3

# %%
df = pd.read_sql_query("""
DROP TABLE CFINAL;
CREATE TABLE CFINAL(AUTHORID VARCHAR(30), TOTALPROFITS FLOAT(30)
);
INSERT INTO CFINAL
	SELECT * FROM C3;
""", engine)
df
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1282                 if not evt_handled:
# -> 1283                     self.dialect.do_execute(
#    1284                         cursor, statement, parameters, context
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     589     def do_execute(self, cursor, statement, parameters, context=None):
# --> 590         cursor.execute(statement, parameters)
#     591
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     327         self._clear_result()
# --> 328         conn.query(q)
#     329         self._do_get_result()
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     516         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 517         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     518         return self._affected_rows
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     731             result = MySQLResult(self)
# --> 732             result.read()
#     733         self._result = result
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in read(self)
#    1074         try:
# -> 1075             first_packet = self.connection._read_packet()
#    1076
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     683         packet = packet_type(buff, self.encoding)
# --> 684         packet.check_error()
#     685         return packet
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\protocol.py in check_error(self)
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# ProgrammingError: (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'CREATE TABLE CFINAL(AUTHORID VARCHAR(30), TOTALPROFITS FLOAT(30)\n);\nINSERT INTO ' at line 2")
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-15-19f437503d52> in <module>
# ----> 1 df = pd.read_sql_query("""
#       2 DROP TABLE CFINAL;
#       3 CREATE TABLE CFINAL(AUTHORID VARCHAR(30), TOTALPROFITS FLOAT(30)
#       4 );
#       5 INSERT INTO CFINAL
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pandas\io\sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     324     """
#     325     pandas_sql = pandasSQL_builder(con)
# --> 326     return pandas_sql.read_query(
#     327         sql,
#     328         index_col=index_col,
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1216         args = _convert_params(sql, params)
#    1217
# -> 1218         result = self.execute(*args)
#    1219         columns = result.keys()
#    1220
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1085     def execute(self, *args, **kwargs):
#    1086         """Simple passthrough to SQLAlchemy connectable"""
# -> 1087         return self.connectable.execute(*args, **kwargs)
#    1088
#    1089     def read_table(
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    2242
#    2243         connection = self._contextual_connect(close_with_result=True)
# -> 2244         return connection.execute(statement, *multiparams, **params)
#    2245
#    2246     def scalar(self, statement, *multiparams, **params):
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#    1010         """
#    1011         if isinstance(object_, util.string_types[0]):
# -> 1012             return self._execute_text(object_, multiparams, params)
#    1013         try:
#    1014             meth = object_._execute_on_connection
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\base.py in _execute_text(self, statement, multiparams, params)
#    1179         dialect = self.dialect
#    1180         parameters = _distill_params(multiparams, params)
# -> 1181         ret = self._execute_context(
#    1182             dialect,
#    1183             dialect.execution_ctx_cls._init_statement,
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1321
#    1322         except BaseException as e:
# -> 1323             self._handle_dbapi_exception(
#    1324                 e, statement, parameters, cursor, context
#    1325             )
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1515                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1516             elif should_wrap:
# -> 1517                 util.raise_(
#    1518                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1519                 )
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1281                             break
#    1282                 if not evt_handled:
# -> 1283                     self.dialect.do_execute(
#    1284                         cursor, statement, parameters, context
#    1285                     )
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     588
#     589     def do_execute(self, cursor, statement, parameters, context=None):
# --> 590         cursor.execute(statement, parameters)
#     591
#     592     def do_execute_no_params(self, cursor, statement, context=None):
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     168         query = self.mogrify(query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#     172         return result
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     326         self._last_executed = q
#     327         self._clear_result()
# --> 328         conn.query(q)
#     329         self._do_get_result()
#     330         return self.rowcount
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     515                 sql = sql.encode(self.encoding, 'surrogateescape')
#     516         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 517         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     518         return self._affected_rows
#     519
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     730         else:
#     731             result = MySQLResult(self)
# --> 732             result.read()
#     733         self._result = result
#     734         if result.server_status is not None:
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in read(self)
#    1073     def read(self):
#    1074         try:
# -> 1075             first_packet = self.connection._read_packet()
#    1076
#    1077             if first_packet.is_ok_packet():
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     682
#     683         packet = packet_type(buff, self.encoding)
# --> 684         packet.check_error()
#     685         return packet
#     686
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\protocol.py in check_error(self)
#     218             errno = self.read_uint16()
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#     222     def dump(self):
#
# c:\users\34635\appdata\local\programs\python\python38\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     107         errval = data[3:].decode('utf-8', 'replace')
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# ProgrammingError: (pymysql.err.ProgrammingError) (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'CREATE TABLE CFINAL(AUTHORID VARCHAR(30), TOTALPROFITS FLOAT(30)\n);\nINSERT INTO ' at line 2")
# [SQL:
# DROP TABLE CFINAL;
# CREATE TABLE CFINAL(AUTHORID VARCHAR(30), TOTALPROFITS FLOAT(30)
# );
# INSERT INTO CFINAL
# 	SELECT * FROM C3;
# ]
# (Background on this error at: http://sqlalche.me/e/f405)

# %%
## En el 3er challenge entendí que tenía que haber hecho en todo el 2do challenge :(
## Me ha costado bastante estos labs y la verdad que he aprendido a base de errores y poder ver que mis compañeros también..
## han tenido dificultades y poder ir echandonos una mano con planteamientos
