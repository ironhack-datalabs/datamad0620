# %% [markdown]
# ## Before you start :
#    - These exercises are related to the Exploratory data analysis using matplotlib and seaborn.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - The datasets for Challenge 2 and 3 are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### Import all the libraries that are necessary.

# %%
# import libraries here
import numpy as np

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Define data.

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x,y) and (x,z) on the axes.
#
# #### There are 2 ways of doing this. Do in both ways.
#
# *Hint: Check out the `nrows`, `ncols`, and `index` arguments of [subplots](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplot.html)*
#
# #### Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# your code here-1st way (call `subplots` twice using the `index` parameter)
plt.subplot(1,2,1)
plt.plot(x,y, "g+")
plt.subplot(1,2,2)
plt.plot(x,z)

# %%
# your code here-2st way (call `subplots` only once not using the `index` parameter)
fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.plot(x,y, "g+")
ax2.plot(x, z)

# %% [markdown]
# #### Augmenting your previous code, resize your previous plot.
#
# *Hint: Add the `figsize` argument in `plt.subplots()`*

# %%
# your code here
# your code here-2st way (call `subplots` only once not using the `index` parameter)
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(24, 6))
ax1.plot(x,y, "g+")
ax2.plot(x, z)

# %% [markdown]
# #### Augmenting your previous code, label your axes.
#
# *Hint: call `set_xlabel` and `set_ylabel`*

# %%
# your code here
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(24, 6))
ax1.plot(x,y, "g+")
ax1.set_xlabel("x")
ax1.set_ylabel("y")
ax2.plot(x, z)
ax2.set_xlabel("x")
ax2.set_ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# #### Plot both `y=x^2` and `y=exp(x)` in the same plot using normal and logarithmic scale.
#
# *Hint: Use `set_xscale` and `set_yscale`*

# %%
# your code here
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(30, 10))
ax1.plot(x,np.exp(x), "-")
ax1.plot(x,x**2, "-")
ax1.set_xlabel("x")
ax1.set_ylabel("y")
ax1.set_xscale("linear")
ax1.set_yscale("linear")


ax2.plot(x,np.exp(x), "g+")
ax2.plot(x,x**2)
ax2.set_xlabel("x")
ax2.set_ylabel("y")
ax2.set_xscale("linear")
ax2.set_yscale("log")

# %% [markdown]
# #### In the vehicles data set that you have downloaded, use the vehicles.csv file. In this exercise we will conduct some exploratory data analysis using one plot each of scatter plot, box plot, histogram, and bar chart.

# %% [markdown]
# Scatter Plot
#
# Please provide a scatter plot between "Combined MPG" as X variable and
# "Highway MPG" as Y variable

# %%
df = pd.read_csv("vehicles.csv")

# %%
plt.scatter(df["Combined MPG"], df["Highway MPG"])

# %% [markdown]
# Box Whisker Plot
#
# Please provide a box plot of the variable "CO2 Emission Grams/mile"

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Displacement', 'Cylinders',
#        'Transmission', 'Drivetrain', 'Vehicle Class', 'Fuel Type',
#        'Fuel Barrels/Year', 'City MPG', 'Highway MPG', 'Combined MPG',
#        'CO2 Emission Grams/Mile', 'Fuel Cost/Year'],
#       dtype='object')

# %%
sns.boxplot(y="CO2 Emission Grams/Mile", data=df)

# %% [markdown]
# Histogram
#
# Please provide a histogram of the Fuel Barrels/Year

# %%
plt.hist(df["Fuel Barrels/Year"], bins=5)
# Out:
# (array([  455., 23804., 11062.,   605.,    26.]),
#  array([ 0.06      ,  9.46542857, 18.87085714, 28.27628571, 37.68171429,
#         47.08714286]),
#  <a list of 5 Patch objects>)

# %% [markdown]
# Bar Chart
#
# Please provide a bar chart of the Fuel Type on the X axis and "City MPG" on the Y axis

# %%
df.plot(x= "Fuel Type", y="City MPG", kind="bar")
plt.xlabel("Fuel Type")
plt.ylabel("City MPG")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-5df909f9d44e> in <module>
# ----> 1 df.plot(x= "Fuel Type", y="City MPG", kind="bar")
#       2 plt.xlabel("Fuel Type")
#       3 plt.ylabel("City MPG")
#
# ~/.local/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# ~/.local/lib/python3.6/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~/.local/lib/python3.6/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     261         self._compute_plot_data()
#     262         self._setup_subplots()
# --> 263         self._make_plot()
#     264         self._add_table()
#     265         self._make_legend()
#
# ~/.local/lib/python3.6/site-packages/pandas/plotting/_matplotlib/core.py in _make_plot(self)
#    1403                     label=label,
#    1404                     log=self.log,
# -> 1405                     **kwds,
#    1406                 )
#    1407             self._add_legend_handle(rect, label, index=i)
#
# ~/.local/lib/python3.6/site-packages/pandas/plotting/_matplotlib/core.py in _plot(cls, ax, x, y, w, start, log, **kwds)
#    1328     @classmethod
#    1329     def _plot(cls, ax, x, y, w, start=0, log=False, **kwds):
# -> 1330         return ax.bar(x, y, w, bottom=start, log=log, **kwds)
#    1331
#    1332     @property
#
# ~/.local/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/.local/lib/python3.6/site-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2402             elif orientation == 'horizontal':
#    2403                 r.sticky_edges.x.append(l)
# -> 2404             self.add_patch(r)
#    2405             patches.append(r)
#    2406
#
# ~/.local/lib/python3.6/site-packages/matplotlib/axes/_base.py in add_patch(self, p)
#    1917         if p.get_clip_path() is None:
#    1918             p.set_clip_path(self.patch)
# -> 1919         self._update_patch_limits(p)
#    1920         self.patches.append(p)
#    1921         p._remove_method = self.patches.remove
#
# ~/.local/lib/python3.6/site-packages/matplotlib/axes/_base.py in _update_patch_limits(self, patch)
#    1944
#    1945             updatex, updatey = patch.get_transform().\
# -> 1946                 contains_branch_seperately(self.transData)
#    1947             self.update_datalim(xys, updatex=updatex,
#    1948                                 updatey=updatey)
#
# ~/.local/lib/python3.6/site-packages/matplotlib/transforms.py in contains_branch_seperately(self, other_transform)
#    1332         # for a non-blended transform each separate dimension is the same, so
#    1333         # just return the appropriate shape.
# -> 1334         return [self.contains_branch(other_transform)] * 2
#    1335
#    1336     def __sub__(self, other):
#
# ~/.local/lib/python3.6/site-packages/matplotlib/transforms.py in contains_branch(self, other)
#    1312         # check that a subtree is equal to other (starting from self)
#    1313         for _, sub_tree in self._iter_break_from_left_to_right():
# -> 1314             if sub_tree == other:
#    1315                 return True
#    1316         return False
#
# ~/.local/lib/python3.6/site-packages/matplotlib/transforms.py in __eq__(self, other)
#    2335     def __eq__(self, other):
#    2336         if isinstance(other, (CompositeGenericTransform, CompositeAffine2D)):
# -> 2337             return self is other or (self._a == other._a
#    2338                                      and self._b == other._b)
#    2339         else:
#
# ~/.local/lib/python3.6/site-packages/matplotlib/transforms.py in __eq__(self, other)
#    1638
#    1639     def __eq__(self, other):
# -> 1640         return self._child.__eq__(other)
#    1641
#    1642     def __str__(self):
#
# ~/.local/lib/python3.6/site-packages/matplotlib/transforms.py in __eq__(self, other)
#    2095             return (self._x == other._x) and (self._y == other._y)
#    2096         elif self._x == self._y:
# -> 2097             return self._x == other
#    2098         else:
#    2099             return NotImplemented
#
# ~/.local/lib/python3.6/site-packages/matplotlib/transforms.py in __eq__(self, other)
#    1709     def __eq__(self, other):
#    1710         if getattr(other, "is_affine", False):
# -> 1711             return np.all(self.get_matrix() == other.get_matrix())
#    1712         return NotImplemented
#    1713
#
# <__array_function__ internals> in all(*args, **kwargs)
#
# ~/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py in all(a, axis, out, keepdims)
#    2409
#    2410     """
# -> 2411     return _wrapreduction(a, np.logical_and, 'all', axis, None, out, keepdims=keepdims)
#    2412
#    2413
#
# ~/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      69
#      70 def _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs):
# ---> 71     passkwargs = {k: v for k, v in kwargs.items()
#      72                   if v is not np._NoValue}
#      73
#
# KeyboardInterrupt:
