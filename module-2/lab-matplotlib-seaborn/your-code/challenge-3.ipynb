# %% [markdown]
# # Challenge 3

# %%
# import libraries here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Import the titanic file. Name your dataset `titanic`.

# %%
titanic = pd.read_csv('./titanic.csv',low_memory=False)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
#
# *Hint: Use Pandas `select_dtypes`*

# %%
titanic.select_dtypes(include=["float64"]).head()
# Out:
#    Survived   Age     Fare
# 0       0.0  22.0   7.2500
# 1       1.0  38.0  71.2833
# 2       1.0  26.0   7.9250
# 3       1.0  35.0  53.1000
# 4       0.0  35.0   8.0500

# %%
titanic.select_dtypes(exclude=["float64"]).head()
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#    Gender  SibSp  Parch            Ticket Cabin Embarked
# 0    male      1      0         A/5 21171    U0        S
# 1  female      1      0          PC 17599   C85        C
# 2  female      0      0  STON/O2. 3101282    U0        S
# 3  female      1      0            113803  C123        S
# 4    male      0      0            373450    U0        S

# %% [markdown]
# #### Set the plot style to `classic` and the figure size to `(12,6)`
#
# *Hint: To set the style you can use `matplotlib.pyplot` functions or seaborn*

# %%
plt.style.use("classic")
plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# #### Use the appropriate visulalization to show the distribution of the column `Age`

# %%
titanic["Age"].plot(kind="hist", bins=20)

# %% [markdown]
# #### Use subplots to plot the distribution of the `Age` variable with bins equal to `10`, `20` and `50`.

# %%
fig,ax=plt.subplots(1,3, figsize=(15,6))
plt.sca(ax[0])
titanic["Age"].plot(kind="hist", bins=10)
plt.title("Age people titanic, bins=10")
plt.xlabel("Age")
plt.sca(ax[1])
plt.xlabel("Age")
titanic["Age"].plot(kind="hist", bins=20)
plt.title("Age people titanic, bins=20")
plt.sca(ax[2])
plt.xlabel("Age")
titanic["Age"].plot(kind="hist", bins=50)
plt.title("Age people titanic, bins=50")
# Out:
# Text(0.5, 1.0, 'Age people titanic, bins=50')

# %% [markdown]
# #### Whether the bin size affects your plot? Why?

# %% [markdown]
# Yes it does. It determines the amount of bars of the histogram. If there are more bins, the size of the bar will be less spread out so the frequency will be more accurate.

# %% [markdown]
# #### Use seaborn to show the distribution of the column `Age`

# %%
sns.distplot(titanic["Age"], bins=30, kde=False)

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Gender`. There are 2 ways of doing it. Do it both ways.
#
# *Hint: Use matplotlib and seaborn*

# %%
# your code here- 1st way
titanic["Gender"].value_counts().plot(kind="bar", color=["g","b"], lw=2)
plt.title("Frequency of Gender at the Titanic")
plt.ylabel("frequency")
# Out:
# Text(0, 0.5, 'frequency')

# %%
# your code here- 2nd way
sns.countplot(x="Gender", data=titanic)
plt.title("Frequency of Gender at the Titanic")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Pclass`

# %%
# your code here
titanic["Pclass"].value_counts().plot(kind="bar", color=["g","b","r"])

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. Choose the appropriate plot to show below.

# %%
# your code here
sns.boxplot(x="Age",data=titanic)

# %% [markdown]
# #### What does the previous plot tell you about the feature `Age`? Comment.

# %%
# your comment here

# %% [markdown]
# #### Now in addition to the summary statistics, we also want to visualize the distribution of `Age`. Choose the appropriate plot to sow below.

# %%
#your code here

# %% [markdown]
# #### What additional information in the previous plot provide you about the feature `Age`? Comment.

# %%
#your comment here

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the appropriate plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
#
# *Hint: One of the ways involves using Seaborn*

# %%
#your code-1st way
sns.scatterplot(x="Age",y="Fare", data=titanic)

# %%
# your code-2nd way

# %% [markdown]
# #### Using Seaborn plot the correlation matrix of various features.
#
# *Hint: search how to use `heatmap`*

# %%
sns.heatmap(titanic.corr(), vmax=0, vmin=1)

# %% [markdown]
# #### According to the previous plot, what are the most correlated feature? Comment.

# %%
#your comment here

# %% [markdown]
# #### Use the appropriate plot to display the summary statistics of the `Age` in function of the `Pclass`.
#
# *Hint: use boxplot to display summary statistics of `Age` in relation to each of the discrete values of `Pclass`*

# %%
#your code here
sns.boxplot(x="Pclass", y="Age", data=titanic, palette="Accent_r")

# %% [markdown]
# #### Use the appropriate plot to display the distributions of  `Age` in relation to  `Gender`.
#
# *Hint: use Facetgrid to display the distribution of `Age` for each categorical value of `Gender`*

# %%
#your code here
g=sns.FacetGrid(titanic, col="Gender")
g.map(plt.hist, "Age", bins=20, color="r")
