# %% [markdown]
# # Challenge 3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Import the titanic file. Name your dataset `titanic`.

# %%
titanic = pd.read_csv('./titanic.csv',low_memory=False)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
#
# *Hint: Use Pandas `select_dtypes`*

# %%
titanic.select_dtypes(exclude=object).head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0            1       0.0       3  22.0      1      0   7.2500
# 1            2       1.0       1  38.0      1      0  71.2833
# 2            3       1.0       3  26.0      0      0   7.9250
# 3            4       1.0       1  35.0      1      0  53.1000
# 4            5       0.0       3  35.0      0      0   8.0500

# %%
titanic.select_dtypes(exclude=(int, float)).head()
# Out:
#                                                 Name  Gender  \
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
#
#              Ticket Cabin Embarked
# 0         A/5 21171    U0        S
# 1          PC 17599   C85        C
# 2  STON/O2. 3101282    U0        S
# 3            113803  C123        S
# 4            373450    U0        S

# %%
titanic.select_dtypes(include=["object"]).head()

# or titanic.select_dtypes(exclude=(int, float)).head()
# Out:
#                                                 Name  Gender  \
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
#
#              Ticket Cabin Embarked
# 0         A/5 21171    U0        S
# 1          PC 17599   C85        C
# 2  STON/O2. 3101282    U0        S
# 3            113803  C123        S
# 4            373450    U0        S

# %% [markdown]
# #### Set the plot style to `classic` and the figure size to `(12,6)`
#
# *Hint: To set the style you can use `matplotlib.pyplot` functions or seaborn*

# %%
plt.style.use("classic")
#with seaborn
sns.set_style("dark")


plt.rcParams["figure.figsize"] = (12, 6)

# %% [markdown]
# #### Use the appropriate visulalization to show the distribution of the column `Age`

# %%
# or titanic["Age"].hist(bins=30);

plt.hist(titanic["Age"], bins=30,color="pink", edgecolor="red");

# %% [markdown]
# #### Use subplots to plot the distribution of the `Age` variable with bins equal to `10`, `20` and `50`.

# %%
plt.subplot(1,3,1) #1 row 3 columns pos0
plt.hist(titanic["Age"], bins=10, color="pink", edgecolor="yellowgreen")

plt.subplot(1,3,2)
plt.hist(titanic["Age"], bins=20, color="pink", edgecolor="yellowgreen")

plt.subplot(1,3,3)
plt.hist(titanic["Age"], bins=50, color="pink", edgecolor="yellowgreen");

# %% [markdown]
# #### Whether the bin size affects your plot? Why?

# %%
# It groups the same amount of data in bigger or smaller batches 
# for visual purposes and/or my man kernell's health

# %% [markdown]
# #### Use seaborn to show the distribution of the column `Age`

# %%
sns.distplot(titanic["Age"],bins=30,kde=False,color='purple');

#kde = Whether to plot a gaussian kernel density estimate

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Gender`. There are 2 ways of doing it. Do it both ways.
#
# *Hint: Use matplotlib and seaborn*

# %%
titanic["Gender"].value_counts().plot(kind="bar", color="pink")
plt.xlabel("Gender")
plt.ylabel("Count");

# plt.bar(x=titanic["Gender"]) otra manera..?

# %%
sns.countplot(x="Gender", data=titanic, color="pink");

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Pclass`

# %%
titanic["Pclass"].value_counts().plot(kind="bar", color="mediumpurple")
plt.xlabel("Class")
plt.ylabel("Values");

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. Choose the appropriate plot to show below.

# %%
sns.boxplot(x="Age",data=titanic, palette="vlag");

# %%
# different way of doing it

titanic.boxplot(column="Age");

# %% [markdown]
# #### What does the previous plot tell you about the feature `Age`? Comment.

# %%
# The median stands at 28
# The 25th percentile at 22
# The 75th percentile at 37
#    And so the interquartile Range (IQR) goes from 22 to 37
# The minimum at 0
# The maximum at 59
#    There are quite a few outliers above the max but none beneath the min 
#       unless you truly question the concept of time in which case there would also be
#       some outliers beneath 0 (sorry for that)

# %% [markdown]
# #### Now in addition to the summary statistics, we also want to visualize the distribution of `Age`. Choose the appropriate plot to sow below.

# %%
sns.distplot(titanic["Age"],bins=30,color='purple');

# kde allows us to plot a gaussian kernel ¡¡¡density!!! estimate

# %%
# This works too.. (same thing as the density estimate but made symmetric)

sns.violinplot("Age", data=titanic, color="mediumpurple")

# %% [markdown]
# #### What additional information in the previous plot provide you about the feature `Age`? Comment.

# %%
# The violin plot features a kernel density estimation of the underlying distribution.

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the appropriate plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
#
# *Hint: One of the ways involves using Seaborn*

# %%
#your code-1st way

# %%
sns.regplot(x="Age", y="Fare", data=titanic, color="orchid");

# %%
sns.jointplot(x="Age",y="Fare", data=titanic, color="orchid");

# %% [markdown]
# #### Using Seaborn plot the correlation matrix of various features.
#
# *Hint: search how to use `heatmap`*

# %%
sns.heatmap(titanic.corr(), linewidths=5, cmap='Pastel1')

# %% [markdown]
# #### According to the previous plot, what are the most correlated feature? Comment.

# %%
#SibSp and Parch

# %% [markdown]
# #### Use the appropriate plot to display the summary statistics of the `Age` in function of the `Pclass`.
#
# *Hint: use boxplot to display summary statistics of `Age` in relation to each of the discrete values of `Pclass`*

# %%
sns.boxplot(x='Pclass',y='Age',data=titanic,palette='colorblind');

# %% [markdown]
# #### Use the appropriate plot to display the distributions of  `Age` in relation to  `Gender`.
#
# *Hint: use Facetgrid to display the distribution of `Age` for each categorical value of `Gender`*

# %%
p = sns.FacetGrid(data=titanic,col="Gender")
p.map(plt.hist,"Age")
